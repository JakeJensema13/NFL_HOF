# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import os

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
    
df = pd.read_csv("/kaggle/input/nfl-pro-football-hall-of-fame-19632022/nflhofplayers.csv")
# Out:
# /kaggle/input/nfl-pro-football-hall-of-fame-19632022/nflhofplayers.csv

# %%
df.head()
# Out:
#    id  rank           player position  year_inducted  from    to  \
# 0   1     1     Tony Boselli        T           2022  1995  2001
# 1   2     2     Cliff Branch       WR           2022  1972  1985
# 2   3     3     LeRoy Butler       DB           2022  1990  2001
# 3   4     4        Sam Mills       LB           2022  1986  1997
# 4   5     5  Richard Seymour       DE           2022  2001  2012
#
#    all_pro_selections  pro_bowl_selections  years_as_starter  ...  \
# 0                   3                    5                 6  ...
# 1                   3                    4                11  ...
# 2                   4                    4                11  ...
# 3                   1                    5                11  ...
# 4                   3                    7                11  ...
#
#    longest_rush  receptions  receiving_yards  receiving_td  longest_reception  \
# 0           NaN         NaN              NaN           NaN                NaN
# ...

# %%
df.describe()
# Out:
#                id        rank  year_inducted         from           to  \
# count  306.000000  306.000000     306.000000   306.000000   306.000000
# mean   153.500000  153.500000    1994.392157  1965.885621  1977.823529
# std     88.478811   88.478811      18.782879    20.760065    21.869394
# min      1.000000    1.000000    1963.000000  1920.000000  1926.000000
# 25%     77.250000   77.250000    1978.000000  1952.000000  1964.000000
# 50%    153.500000  153.500000    1996.000000  1967.000000  1978.000000
# 75%    229.750000  229.750000    2011.750000  1983.000000  1996.750000
# max    306.000000  306.000000    2022.000000  2007.000000  2015.000000
#
#        all_pro_selections  pro_bowl_selections  years_as_starter  \
# count          306.000000           306.000000        306.000000
# mean             3.225490             6.013072         10.745098
# std              2.200925             3.213674          3.170622
# min              0.000000             0.000000          0.000000
# ...

# %%
df.loc[df.position == 'WR'].describe()
# Out:
#                id        rank  year_inducted         from           to  \
# count   22.000000   22.000000      22.000000    22.000000    22.000000
# mean    88.363636   88.363636    2007.954545  1981.090909  1994.500000
# std     65.989570   65.989570      12.392307    12.161254    12.308534
# min      2.000000    2.000000    1983.000000  1964.000000  1977.000000
# 25%     38.250000   38.250000    2001.250000  1972.250000  1984.250000
# 50%     78.000000   78.000000    2011.500000  1979.000000  1994.000000
# 75%    131.000000  131.000000    2018.000000  1988.000000  2004.000000
# max    211.000000  211.000000    2022.000000  2007.000000  2015.000000
#
#        all_pro_selections  pro_bowl_selections  years_as_starter  \
# count           22.000000             22.00000         22.000000
# mean             2.045455              6.00000         12.227273
# std              2.235584              2.56348          2.223935
# min              0.000000              3.00000          8.000000
# ...

# %%
df.loc[df.position == 'QB'].describe()
# Out:
#                id        rank  year_inducted         from           to  \
# count   29.000000   29.000000      29.000000    29.000000    29.000000
# mean   177.068966  177.068966    1989.655172  1966.827586  1981.068966
# std     81.648170   81.648170      17.728661    18.057584    18.523983
# min     10.000000   10.000000    1963.000000  1937.000000  1950.000000
# 25%    116.000000  116.000000    1977.000000  1949.000000  1971.000000
# 50%    189.000000  189.000000    1987.000000  1967.000000  1979.000000
# 75%    235.000000  235.000000    2005.000000  1983.000000  1998.000000
# max    296.000000  296.000000    2021.000000  1998.000000  2015.000000
#
#        all_pro_selections  pro_bowl_selections  years_as_starter  \
# count           29.000000            29.000000         29.000000
# mean             2.241379             6.586207         12.172414
# std              1.902164             2.706041          3.185559
# min              0.000000             2.000000          6.000000
# ...

# %%
df.loc[df.position == 'RB'].describe()
# Out:
#                id        rank  year_inducted         from           to  \
# count   22.000000   22.000000      22.000000    22.000000    22.000000
# mean   129.772727  129.772727    2000.000000  1980.318182  1990.909091
# std     63.591653   63.591653      13.480144    13.371563    13.433820
# min     21.000000   21.000000    1972.000000  1952.000000  1966.000000
# 25%     81.000000   81.000000    1991.250000  1969.500000  1980.250000
# 50%    130.000000  130.000000    2001.000000  1980.000000  1990.500000
# 75%    169.750000  169.750000    2010.750000  1992.250000  2003.250000
# max    251.000000  251.000000    2020.000000  2001.000000  2011.000000
#
#        all_pro_selections  pro_bowl_selections  years_as_starter  \
# count           22.000000            22.000000         22.000000
# mean             2.909091             5.681818         10.090909
# std              1.659291             2.056033          2.307526
# min              1.000000             1.000000          5.000000
# ...

# %%
WR_data = df.loc[df.position == 'WR']

fig = px.bar(WR_data, x = 'player', y = 'years_as_starter',color = 'years_as_starter', title = 'HOF WR Years Starting')

fig.update_layout(template = 'plotly_dark', xaxis_title = 'Player Name', yaxis_title = 'Years As Starter')

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
RB_Data = df.loc[df.position == 'RB']

fig = px.scatter(RB_Data, x = 'player', y = 'longest_rush', color = 'player')


fig.show()
# Out:
# <div>                            <div id="c7421533-0c15-47ce-811a-8f402c28a110" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7421533-0c15-47ce-811a-8f402c28a110")) {                    Plotly.newPlot(                        "c7421533-0c15-47ce-811a-8f402c28a110",                        [{"hovertemplate":"player=%{x}<br>longest_rush=%{y}<extra></extra>","legendgroup":"Edgerrin James","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Edgerrin James","orientation":"v","showlegend":true,"x":["Edgerrin James"],"xaxis":"x","y":[72.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"player=%{x}<br>longest_rush=%{y}<extra></extra>","legendgroup":"Terrell Davis","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"
# ...

# %%
df['Years_Active'] = df['to'] - df['from']

fig = px.box(df, x='position' ,y='Years_Active', color = 'position', title = 'Years active per position')

fig.update_layout(template = 'plotly_dark', font = dict(family = 'Arial', size = 16))

fig.show()
# Out:
# <div>                            <div id="5ca16359-4539-4aed-9e73-466a19c76db2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ca16359-4539-4aed-9e73-466a19c76db2")) {                    Plotly.newPlot(                        "5ca16359-4539-4aed-9e73-466a19c76db2",                        [{"alignmentgroup":"True","hovertemplate":"position=%{x}<br>Years_Active=%{y}<extra></extra>","legendgroup":"T","marker":{"color":"#636efa"},"name":"T","notched":false,"offsetgroup":"T","orientation":"v","showlegend":true,"x":["T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T","T"],"x0":" ","xaxis":"x","y":[6,7,14,9,12,11,11,12,11,12,9,19,14,12,9,12,10,14,11,11,15,12,7,21,10,9,8,10,7,12,8,9],
# ...

# %%
df.loc[df.Years_Active > 20]
# Out:
#       id  rank           player position  year_inducted  from    to  \
# 40    41    41  Morten Andersen        K           2017  1982  2007
# 216  217   217    George Blanda       QB           1981  1949  1975
# 244  245   245        Lou Groza        T           1974  1946  1967
#
#      all_pro_selections  pro_bowl_selections  years_as_starter  ...  \
# 40                    3                    7                 0  ...
# 216                   1                    4                 9  ...
# 244                   4                    9                12  ...
#
#      receptions  receiving_yards  receiving_td  longest_reception  \
# 40          NaN              NaN           NaN                NaN
# 216         1.0            -16.0           0.0                7.0
# 244         1.0             23.0           1.0               23.0
#
#      all_purpose_yards  td_total  tackles  sacks  interception  Years_Active
# ...

# %%
fig = px.pie(df, values = 'pro_bowl_selections', names= 'position', title = 'Total Pro Bowl Selections By Poition', hover_data = ['all_pro_selections'])
fig.show()
# Out:
# <div>                            <div id="f1c485f4-b4c1-459c-9985-d3205c01bc0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1c485f4-b4c1-459c-9985-d3205c01bc0e")) {                    Plotly.newPlot(                        "f1c485f4-b4c1-459c-9985-d3205c01bc0e",                        [{"customdata":[[3],[3],[4],[1],[3],[1],[6],[3],[2],[7],[3],[3],[2],[0],[0],[2],[4],[3],[0],[5],[1],[3],[4],[3],[0],[3],[0],[3],[6],[2],[3],[5],[6],[2],[4],[5],[7],[4],[5],[4],[3],[3],[3],[3],[3],[2],[3],[2],[3],[3],[1],[5],[2],[0],[2],[6],[2],[5],[5],[3],[2],[4],[0],[4],[3],[6],[2],[1],[4],[2],[4],[3],[6],[2],[3],[1],[4],[1],[3],[3],[1],[6],[4],[3],[0],[0],[1],[6],[10],[4],[2],[7],[8],[2],[6],[2],[1],[1],[1],[2],[3],[3],[1],[7],[2],[2],[3],[0],[0],[0],[8],[3],[4]
# ...

# %%
QB_data = df.loc[df.position == 'QB']
sortedQB_data = QB_data.sort_values(by='pass_td')
fig = px.bar(sortedQB_data, x= 'player', y= 'pass_td', color= 'pass_td', title = 'HOF QB Total TD Thrown')

fig.update_layout(yaxis_title = 'TD Thrown', template = 'plotly_dark', font = dict(family = 'Verdana', size = 13))
fig.show()
# Out:
# <div>                            <div id="1528f239-8ba5-4880-86fd-6829abf0d1bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1528f239-8ba5-4880-86fd-6829abf0d1bd")) {                    Plotly.newPlot(                        "1528f239-8ba5-4880-86fd-6829abf0d1bd",                        [{"alignmentgroup":"True","hovertemplate":"player=%{x}<br>pass_td=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[97.0,137.0,152.0,153.0,165.0,173.0,173.0,174.0,187.0,192.0,194.0,196.0,208.0,212.0,232.0,236.0,237.0,239.0,242.0,254.0,255.0,273.0,290.0,291.0,300.0,342.0,420.0,508.0,539.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Bob Waterfield","Sid
# ...

# %%
sortedQB_data['QB_TD'] = df['pass_td'] / (df['to'] - df['from'])

fig = px.bar(sortedQB_data, x='player', y='QB_TD', title = 'Average QB Passing TD Per Year')

fig.update_layout(template = 'ggplot2')
fig.show()
# Out:
# <div>                            <div id="3fd4e786-f9a3-4149-bc91-e66ef665eaa3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3fd4e786-f9a3-4149-bc91-e66ef665eaa3")) {                    Plotly.newPlot(                        "3fd4e786-f9a3-4149-bc91-e66ef665eaa3",                        [{"alignmentgroup":"True","hovertemplate":"player=%{x}<br>QB_TD=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Bob Waterfield","Sid Luckman","Bart Starr","Roger Staubach","Troy Aikman","Norm Van Brocklin","Joe Namath","Otto Graham","Sammy Baugh","Bob Griese","Ken Stabler","Bobby Layne","Kurt Warner","Terry Bradshaw","Steve Young","
# ...

# %%
WR_RB_Data = df.loc[(df.position == 'RB') | (df.position == 'WR')]
WR_RB_Data['AVG_TD'] = df['td_total'] / (df['to'] - df['from'])
WR_RB_Data_Sorted = WR_RB_Data.sort_values(by='AVG_TD')




fig = px.bar(WR_RB_Data_Sorted, x='player', y= 'AVG_TD')
fig.update_layout(template = 'plotly_dark')
fig.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
